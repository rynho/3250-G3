# %%
# %matplotlib inline
# %precision 3

import numpy as np
from numpy import nan as NA
from numpy.random import randn
from numpy import corrcoef, arange
np.random.seed(123)

import pandas as pd
import os
import datetime
import re

import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import autocorrelation_plot
from pylab import pcolor, show, colorbar, xticks, yticks

plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4)
pd.options.display.max_rows = 10

# %%
#!powershell -command "& {gc NCDB_1999_to_2014.csv -head 10}"
#!powershell -command "& {gc NCDB_1999_to_2014_s.csv -head 10}"

# %%
#accident = pd.read_csv('NCDB_1999_to_2014.csv', engine = 'python')
#accident = pd.read_csv('NCDB_1999_to_2014_s.csv', engine = 'python')
accident = pd.read_csv('../../data/small/NCDB_1999_to_2014-002.csv', engine = 'python') #-- small
#accident = pd.read_csv('../../data/NCDB_1999_to_2014.csv', engine = 'python') # -- full

# %%
#replace all column head to lower case.

accident.columns = accident.columns.map(lambda x: x[:].lower())
accident
# Out:
#          c_year c_mnth c_wday c_hour  c_sev c_vehs c_conf c_rcfg c_wthr  \
# 0          2009     03      5     21      2     02     21     02      1
# 1          2009     03      5     21      2     02     21     02      1
# 2          2009     03      5     21      2     02     21     02      1
# 3          2009     03      5     15      2     02     21     UU      1
# 4          2009     03      5     15      2     02     21     UU      1
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1860400    2014     UU      U     UU      2     UU     UU     01      U
# 1860401    2014     UU      U     23      2     01     06     05      1
# 1860402    2014     UU      U     14      2     01     02     01      1
# 1860403    2014     UU      U     22      1     01     06     01      2
# 1860404    2014     UU      U     22      1     01     06     01      2
#
#         c_rsur  ...   v_id v_type v_year p_id p_sex p_age p_psn p_isev p_safe  \
# 0            Q  ...     01     01   2001   01     M    17    11      1     02
# 1            Q  ...     01     01   2001   02     F    17    13      2     02
# 2            Q  ...     02     01   1992   01     M    18    11      2     02
# 3            2  ...     01     01   2004   01     M    76    11      1     02
# 4            2  ...     02     01   1999   01     F    69    11      2     02
# ...        ...  ...    ...    ...    ...  ...   ...   ...   ...    ...    ...
# 1860400      U  ...     13     07   UUUU   01     M    24    11      1     NN
# 1860401      1  ...     01     14   2006   01     M    29    96      2     09
# 1860402      5  ...     01     01   2006   01     F    UU    11      2     01
# 1860403      4  ...     01     22   UUUU   01     M    67    12      3     01
# 1860404      4  ...     01     22   UUUU   02     M    10    98      1     01
#
#         p_user
# 0            1
# 1            2
# 2            1
# 3            1
# 4            1
# ...        ...
# 1860400      1
# 1860401      5
# 1860402      1
# 1860403      U
# 1860404      U
#
# [1860405 rows x 22 columns]

# %% [markdown]
# ##### Collision level data elements
# <div markdown style="float:left">
#
# |Data element|Columns|Column size|Definition|
# |--|--|--|--|
# |C_YEAR|1 – 4|4|Year|
# |C_MNTH|5 – 6|2|Month|
# |C_WDAY|7|1|Day of week|
# |C_HOUR|8 – 9|2|Collision hour|
# |C_SEV|10|1|Collision severity|
# |C_VEHS|11 – 12|2|Number of vehicles involved in collision|
# |C_CONF|13 – 14|2|Collision configuration|
# |C_RCFG|15 – 16|2|Roadway configuration|
# |C_WTHR|17|1|Weather condition|
# |C_RSUR|18|1|Road surface|
# |C_RALN|19|1|Road alignment|
# |C_TRAF|20 – 21|2|Traffic control|

# %% [markdown]
# ##### Vehicle level data elements
# <div markdown style="float:left">
#
# |Data element|Columns|Column size|Definition|
# |--|--|--|--|
# |V_ID|22 – 23|2|Vehicle sequence number|
# |V_TYPE|24 – 25|2|Vehicle type|
# |V_YEAR|26 – 29|4|Vehicle model year|

# %% [markdown]
# ##### Person level data elements
# <div markdown style="float:left">
#
# |Data element|Columns|Column size|Definition|
# |--|--|--|--|
# |P_ID|30 – 31|2|Person sequence number|
# |P_SEX|32|1|Person sex|
# |P_AGE|33 – 34|2|Person age|
# |P_PSN|35 – 36|2|Person position|
# |P_ISEV|37|1|Medical treatment required|
# |P_SAFE|38 – 39|2|Safety device used|
# |P_USER|40|1|Road user class|

# %% [markdown]
# #### Data cleaning and normalization

# %%
#remove all special values (unknown to us) in date-time columns, prepare for using date series as index.
#make a copy "df" for further analysis, avoid mess up the original data "accident".

df = accident[:]
df[['c_mnth','c_wday','c_hour','c_rcfg','c_wthr','c_rsur','c_traf']]=df[['c_mnth','c_wday','c_hour','c_rcfg','c_wthr','c_rsur','c_traf']].replace('[^0-9]+',np.nan,regex=True)

df.dropna(axis=0,subset=['c_mnth','c_wday','c_hour','c_rcfg','c_wthr','c_rsur','c_traf'],inplace=True)
df
# Out:
#          c_year c_mnth c_wday c_hour  c_sev c_vehs c_conf c_rcfg c_wthr  \
# 43         2009     03      5     08      2     02     35     02      1
# 44         2009     03      5     08      2     02     35     02      1
# 45         2009     03      5     08      2     02     35     02      1
# 88         2009     03      5     18      2     02     21     02      1
# 89         2009     03      5     18      2     02     21     02      1
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1860376    2014     12      7     14      2     02     41     01      1
# 1860377    2014     12      7     14      2     02     41     01      1
# 1860378    2014     12      7     19      2     01     03     01      1
# 1860379    2014     12      7     19      2     01     03     01      1
# 1860380    2014     12      7     19      2     01     03     01      1
#
#         c_rsur  ...   v_id v_type v_year p_id p_sex p_age p_psn p_isev p_safe  \
# 43           1  ...     01     01   2007   01     F    50    11      2     UU
# 44           1  ...     02     01   2009   01     M    37    11      1     UU
# 45           1  ...     02     01   2009   02     F    09    21      1     UU
# 88           2  ...     01     01   2007   01     M    39    11      2     02
# 89           2  ...     01     01   2007   02     M    03    23      1     02
# ...        ...  ...    ...    ...    ...  ...   ...   ...   ...    ...    ...
# 1860376      5  ...     02     05   2008   01     M    44    11      1     02
# 1860377      5  ...     02     05   2008   02     M    34    13      2     02
# 1860378      3  ...     01     01   2001   01     F    35    11      2     02
# 1860379      3  ...     01     01   2001   02     M    26    13      1     02
# 1860380      3  ...     01     01   2001   03     F    15    21      2     02
#
#         p_user
# 43           1
# 44           1
# 45           2
# 88           1
# 89           2
# ...        ...
# 1860376      1
# 1860377      2
# 1860378      1
# 1860379      2
# 1860380      2
#
# [1538065 rows x 22 columns]

# %%
#generate the date-time column "date", and assign it as the index.

#df['date'] = pd.DatetimeIndex(df['c_year'].map(str) + '-' + df['c_mnth'] + '-' + df['c_wday'] + ' ' + df['c_hour'] + ':0:0')
df['date'] = pd.PeriodIndex(df['c_year'].map(str) + '-' + df['c_mnth'], freq='M')
df
# Out:
#          c_year c_mnth c_wday c_hour  c_sev c_vehs c_conf c_rcfg c_wthr  \
# 43         2009     03      5     08      2     02     35     02      1
# 44         2009     03      5     08      2     02     35     02      1
# 45         2009     03      5     08      2     02     35     02      1
# 88         2009     03      5     18      2     02     21     02      1
# 89         2009     03      5     18      2     02     21     02      1
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1860376    2014     12      7     14      2     02     41     01      1
# 1860377    2014     12      7     14      2     02     41     01      1
# 1860378    2014     12      7     19      2     01     03     01      1
# 1860379    2014     12      7     19      2     01     03     01      1
# 1860380    2014     12      7     19      2     01     03     01      1
#
#         c_rsur   ...   v_type v_year p_id p_sex p_age p_psn p_isev p_safe  \
# 43           1   ...       01   2007   01     F    50    11      2     UU
# 44           1   ...       01   2009   01     M    37    11      1     UU
# 45           1   ...       01   2009   02     F    09    21      1     UU
# 88           2   ...       01   2007   01     M    39    11      2     02
# 89           2   ...       01   2007   02     M    03    23      1     02
# ...        ...   ...      ...    ...  ...   ...   ...   ...    ...    ...
# 1860376      5   ...       05   2008   01     M    44    11      1     02
# 1860377      5   ...       05   2008   02     M    34    13      2     02
# 1860378      3   ...       01   2001   01     F    35    11      2     02
# 1860379      3   ...       01   2001   02     M    26    13      1     02
# 1860380      3   ...       01   2001   03     F    15    21      2     02
#
#         p_user    date
# 43           1 2009-03
# 44           1 2009-03
# 45           2 2009-03
# 88           1 2009-03
# 89           2 2009-03
# ...        ...     ...
# 1860376      1 2014-12
# 1860377      2 2014-12
# 1860378      1 2014-12
# 1860379      2 2014-12
# 1860380      2 2014-12
#
# [1538065 rows x 23 columns]

# %%
# this line use 'date' as index, meke 'df' becoming time series.

df=df.set_index('date')
df
# Out:
#          c_year c_mnth c_wday c_hour  c_sev c_vehs c_conf c_rcfg c_wthr  \
# date
# 2009-03    2009     03      5     08      2     02     35     02      1
# 2009-03    2009     03      5     08      2     02     35     02      1
# 2009-03    2009     03      5     08      2     02     35     02      1
# 2009-03    2009     03      5     18      2     02     21     02      1
# 2009-03    2009     03      5     18      2     02     21     02      1
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2014-12    2014     12      7     14      2     02     41     01      1
# 2014-12    2014     12      7     14      2     02     41     01      1
# 2014-12    2014     12      7     19      2     01     03     01      1
# 2014-12    2014     12      7     19      2     01     03     01      1
# 2014-12    2014     12      7     19      2     01     03     01      1
#
#         c_rsur  ...   v_id v_type v_year p_id p_sex p_age p_psn p_isev p_safe  \
# date            ...
# 2009-03      1  ...     01     01   2007   01     F    50    11      2     UU
# 2009-03      1  ...     02     01   2009   01     M    37    11      1     UU
# 2009-03      1  ...     02     01   2009   02     F    09    21      1     UU
# 2009-03      2  ...     01     01   2007   01     M    39    11      2     02
# 2009-03      2  ...     01     01   2007   02     M    03    23      1     02
# ...        ...  ...    ...    ...    ...  ...   ...   ...   ...    ...    ...
# 2014-12      5  ...     02     05   2008   01     M    44    11      1     02
# 2014-12      5  ...     02     05   2008   02     M    34    13      2     02
# 2014-12      3  ...     01     01   2001   01     F    35    11      2     02
# 2014-12      3  ...     01     01   2001   02     M    26    13      1     02
# 2014-12      3  ...     01     01   2001   03     F    15    21      2     02
#
#         p_user
# date
# 2009-03      1
# 2009-03      1
# 2009-03      2
# 2009-03      1
# 2009-03      2
# ...        ...
# 2014-12      1
# 2014-12      2
# 2014-12      1
# 2014-12      2
# 2014-12      2
#
# [1538065 rows x 22 columns]

# %% [markdown]
# #### Proposed analytics:
# 1. Trend over the whole period and seasonality identification
# 2. Correlation between total number of collisions and fatal collisions
# 3. Analysis collision risk for different week days and hours
# 4. Analysis the following factors to collision rate:<br>
#     a) Road configuration<br>
#     b) Weather<br>
#     c) Road surface<br>
#     d) Traffic control<br>

# %% [markdown]
# #### (1) Trend over the whole period and seasonality identification

# %%
df['fatal']=np.where(df['c_sev']==1,1,0)
df['non_fatal']=np.where(df['c_sev']==2,1,0)

# %%
df_1=df.groupby('date')['fatal','non_fatal'].sum()
df_1
# Out:
#          fatal  non_fatal
# date
# 2009-03     96       5143
# 2009-04    279      19408
# 2009-05    295      21943
# 2009-06    390      25304
# 2009-07    522      25229
# ...        ...        ...
# 2014-08    397      22421
# 2014-09    345      21926
# 2014-10    367      22930
# 2014-11    287      20948
# 2014-12    281      19933
#
# [70 rows x 2 columns]

# %%
plot1=df_1.plot(figsize=(15,5),title='Collision overall statistics')
plot1.set_xlabel("Date")
plot1.set_ylabel("Number of collisions")
# Out:
# Text(0,0.5,'Number of collisions')

# %%
plot2=df_1['fatal'].plot(figsize=(15,5),title='Fatal collision statistics')

# %% [markdown]
# ##### Conslusion: The  collision trend declines slightly over years and has pronounced seasonality pattern. The collision peak is in the middle of year and downturn is in Q1.

# %% [markdown]
# #### (2) Correlation between total number of collisions and fatal collisions
# ##### Autocorrelation plot demostrates an obvious seasonality with period of 12 months.

# %%
#Autocorrelation of fatal and non-fatal collisions
plt.figure(figsize=(15,5))
for c in df_1.columns:
    autocorrelation_plot(df_1[c],label=c)

# %% [markdown]
# ##### The fatal and non-fatal collisions have strong positive correlation.

# %%
sns.regplot('fatal', 'non_fatal', data=df_1)

# %% [markdown]
# #### The hitmap shows the correlation coefficient between fatal and non fatal collisions as 0.84

# %%
corr = df_1.corr()
pcolor(corr,cmap='ocean')
colorbar()
yticks([0.5,1.5],df_1.columns)
xticks([0.5,1.5],df_1.columns)

show()

# %% [markdown]
# #### 3.Analysis of collision risk dependancy on different week day and day hours

# %%
# Collisions by weekday
by_weekday = df.groupby('c_wday')['c_sev'].count()
by_weekday
# Out:
# c_wday
# 1    203183
# 2    217931
# 3    221789
# 4    234158
# 5    259361
# 6    221987
# 7    179656
# Name: c_sev, dtype: int64

# %%
by_weekday = df.groupby('c_wday')['c_sev'].count()
by_weekday.index = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
plot2 = by_weekday.plot(kind='bar',title='Collisions by week day')

# %%
# Collisions by hour
plt.figure(figsize=(15,5))
by_hour = df.groupby('c_hour')['c_sev'].count()
plot3 = by_hour.plot(kind='bar',title='Collisions by week hour',color='G')

# %% [markdown]
# ##### Conclusion: The higher collision risk is on Friday and the lowest is on Sunday.
# ##### The riskiest period is from 3 pm to 5 pm. Night hours have the lowest collision risk.

# %% [markdown]
# #### 4.Analysis of the following factors to collision rate:
# ####    a) Road configuration
# ####    b) Weather
# ####    c) Road surface
# ####    d) Traffic control

# %%
#Number of collisions grouped by road configuration
df_2=df.groupby('c_rcfg')['c_sev'].count().sort_values(ascending=True)
df_2
# Out:
# c_rcfg
# 10       255
# 07       270
# 09      1385
# 06      2060
# 08      3877
# 04      5782
# 05     14375
# 03     82614
# 01    613535
# 02    813912
# Name: c_sev, dtype: int64

# %%
df_2.index=['Express lane of a freeway system','Passing or climbing lane','Traffic circle','Tunnel','Ramp',
            'Railroad level crossing','Bridge','Intersection with parking lot entrance/exit',
            'Non-intersection','At an intersection']

# %%
df_2.plot.barh(color='slateblue',figsize=(15,5),title='Collisions by road configuration')

# %%
#Number of collisions grouped by weather condition 
df_3=df.groupby('c_wthr')['c_sev'].count().sort_values(ascending=True)
df_3
# Out:
# c_wthr
# 7       4020
# 5       6442
# 6      21591
# 4      77469
# 2     152493
# 3     166074
# 1    1109976
# Name: c_sev, dtype: int64

# %%
df_3.index=['Strong Wind','Freezing rain, sleet, hail','Fog, smog, mist','Snowing','Overcast, cloudy but no precipitation',
            'Raining','Clear and sunny']
df_3.plot.barh(color='gold',figsize=(15,5),title='Collisions by weather condition')

# %%
#Number of collisions grouped by road surface
df_4=df.groupby('c_rsur')['c_sev'].count().sort_values(ascending=True)
df_4=df_4[-5:] # top 5. The remaining groups are non significant
df_4
# Out:
# c_rsur
# 4      20436
# 3      58256
# 5      81816
# 2     288540
# 1    1079922
# Name: c_sev, dtype: int64

# %%
df_5.index=['Slush, wet snow','Snow (fresh, loose snow)','Icy','Wet','Dry, normal']
df_5.plot.barh(color='darkmagenta',figsize=(15,5),title='Collisions by traffic control')

# %%
#Number of collisions grouped by traffic control
df_5=df.groupby('c_traf')['c_sev'].count().sort_values(ascending=True)
df_5=df_5[-5:] # top 5. The remaining groups are non significant
df_5
# Out:
# c_traf
# 06     10107
# 04     20966
# 03    188876
# 01    484477
# 18    808995
# Name: c_sev, dtype: int64

# %%
df_5.index=['Pedestrian crosswalk','Yield sign','Stop sign',
            'Traffic signals fully operational','No control present']
df_5.plot.barh(color='navy',figsize=(15,5),title='Collisions by traffic control')

# %% [markdown]
# ##### Conclusion: The majority of collisions occur at intersection in a clean and sunny day when road surface is dry and no control signs are present.
# ##### Based on other categories with significant weigth in the collision statistics, we can recommend to be more careful when you drive on wet or icy road and pay attentiomn near stop sign.
