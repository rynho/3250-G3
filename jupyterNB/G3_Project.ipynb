# %%
# %matplotlib inline
# %precision 3

from numpy.random import randn
import numpy as np
import pandas as pd
np.random.seed(123)
import os
import re
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4)
pd.options.display.max_rows = 6

from numpy import nan as NA

# %%
#!powershell -command "& {gc NCDB_1999_to_2014.csv -head 10}"
# !powershell -command "& {gc NCDB_1999_to_2014_s.csv -head 10}"
# Out:
# C_YEAR,C_MNTH,C_WDAY,C_HOUR,C_SEV,C_VEHS,C_CONF,C_RCFG,C_WTHR,C_RSUR,C_RALN,C_TRAF,V_ID,V_TYPE,V_YEAR,P_ID,P_SEX,P_AGE,P_PSN,P_ISEV,P_SAFE,P_USER
# 2013,06,2,12,2,02,21,02,1,1,1,01,02,01,2005,01,M,28,11,2,02,1
# 2013,06,2,09,2,01,06,02,1,1,1,18,01,11,2008,01,F,42,11,1,02,1
# 2013,06,2,09,2,01,06,02,1,1,1,18,01,11,2008,02,M,04,12,2,01,2
# 2013,06,2,09,2,01,06,02,1,1,1,18,01,11,2008,03,F,33,98,2,UU,U
# 2013,06,2,08,2,02,36,02,1,1,3,01,01,01,2005,01,F,44,11,2,02,1
# 2013,06,2,08,2,02,36,02,1,1,3,01,02,01,2002,01,M,51,11,1,02,1
# 2013,06,2,11,2,01,06,02,1,1,2,03,01,01,1997,01,M,45,11,1,02,1
# 2013,06,2,11,2,01,06,02,1,1,2,03,99,NN,NNNN,01,M,19,99,2,13,3
# 2013,06,2,11,2,01,06,02,1,1,1,01,01,01,2012,01,F,33,11,1,02,1

# %%
#accident = pd.read_csv('NCDB_1999_to_2014.csv', engine = 'python')
accident = pd.read_csv('NCDB_1999_to_2014_s.csv', engine = 'python')

# %%
#replace all column head to lower case.

accident.columns = accident.columns.map(lambda x: x[:].lower())
accident
# Out:
#         c_year c_mnth c_wday c_hour  c_sev c_vehs c_conf c_rcfg c_wthr c_rsur  \
# 0         2013     06      2     12      2     02     21     02      1      1
# 1         2013     06      2     09      2     01     06     02      1      1
# 2         2013     06      2     09      2     01     06     02      1      1
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 491545    2014     UU      U     14      2     01     02     01      1      5
# 491546    2014     UU      U     22      1     01     06     01      2      4
# 491547    2014     UU      U     22      1     01     06     01      2      4
#
#         ...   v_id v_type v_year p_id p_sex p_age p_psn p_isev p_safe p_user
# 0       ...     02     01   2005   01     M    28    11      2     02      1
# 1       ...     01     11   2008   01     F    42    11      1     02      1
# 2       ...     01     11   2008   02     M    04    12      2     01      2
# ...     ...    ...    ...    ...  ...   ...   ...   ...    ...    ...    ...
# 491545  ...     01     01   2006   01     F    UU    11      2     01      1
# 491546  ...     01     22   UUUU   01     M    67    12      3     01      U
# 491547  ...     01     22   UUUU   02     M    10    98      1     01      U
#
# [491548 rows x 22 columns]

# %%
#check the non-numberic values in date-time columns

accident[accident['c_mnth'].str.contains('[^0-9]')|
         accident['c_wday'].str.contains('[^0-9]')|
         accident['c_hour'].str.contains('[^0-9]')]
# Out:
#         c_year c_mnth c_wday c_hour  c_sev c_vehs c_conf c_rcfg c_wthr c_rsur  \
# 764       2013     06      2     UU      2     02     21     02      1      1
# 765       2013     06      2     UU      2     02     21     02      1      1
# 839       2013     06      2     UU      1     01     04     UU      1      1
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 491545    2014     UU      U     14      2     01     02     01      1      5
# 491546    2014     UU      U     22      1     01     06     01      2      4
# 491547    2014     UU      U     22      1     01     06     01      2      4
#
#         ...   v_id v_type v_year p_id p_sex p_age p_psn p_isev p_safe p_user
# 764     ...     01     01   2009   01     F    53    11      2     02      1
# 765     ...     02     01   2002   01     F    25    11      1     02      1
# 839     ...     01     01   2006   01     M    34    11      3     01      1
# ...     ...    ...    ...    ...  ...   ...   ...   ...    ...    ...    ...
# 491545  ...     01     01   2006   01     F    UU    11      2     01      1
# 491546  ...     01     22   UUUU   01     M    67    12      3     01      U
# 491547  ...     01     22   UUUU   02     M    10    98      1     01      U
#
# [3470 rows x 22 columns]

# %%
#remove all special values (unknown to us) in date-time columns, prepare for using date series as index.
#make a copy "df" for further analysis, avoid mess up the original data "accident".

df = accident[~accident['c_mnth'].str.contains('[^0-9]')&
              ~accident['c_wday'].str.contains('[^0-9]')&
              ~accident['c_hour'].str.contains('[^0-9]')]
df
# Out:
#         c_year c_mnth c_wday c_hour  c_sev c_vehs c_conf c_rcfg c_wthr c_rsur  \
# 0         2013     06      2     12      2     02     21     02      1      1
# 1         2013     06      2     09      2     01     06     02      1      1
# 2         2013     06      2     09      2     01     06     02      1      1
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 491521    2014     12      7     19      2     01     03     01      1      3
# 491522    2014     12      7     19      2     01     03     01      1      3
# 491523    2014     12      7     19      2     01     03     01      1      3
#
#         ...   v_id v_type v_year p_id p_sex p_age p_psn p_isev p_safe p_user
# 0       ...     02     01   2005   01     M    28    11      2     02      1
# 1       ...     01     11   2008   01     F    42    11      1     02      1
# 2       ...     01     11   2008   02     M    04    12      2     01      2
# ...     ...    ...    ...    ...  ...   ...   ...   ...    ...    ...    ...
# 491521  ...     01     01   2001   01     F    35    11      2     02      1
# 491522  ...     01     01   2001   02     M    26    13      1     02      2
# 491523  ...     01     01   2001   03     F    15    21      2     02      2
#
# [488078 rows x 22 columns]

# %%
#use new dataframe "df1" to generate the date-time index column "date".

df1 = df.loc[:,['c_year','c_mnth','c_wday','c_hour']]
df1['date'] = df1['c_year'].map(str) + '-' + df1['c_mnth'] + '-' + df1['c_wday'] + ' ' + df1['c_hour'] + ':0:0'
df1
# Out:
#         c_year c_mnth c_wday c_hour              date
# 0         2013     06      2     12  2013-06-2 12:0:0
# 1         2013     06      2     09  2013-06-2 09:0:0
# 2         2013     06      2     09  2013-06-2 09:0:0
# ...        ...    ...    ...    ...               ...
# 491521    2014     12      7     19  2014-12-7 19:0:0
# 491522    2014     12      7     19  2014-12-7 19:0:0
# 491523    2014     12      7     19  2014-12-7 19:0:0
#
# [488078 rows x 5 columns]

# %%
# merge column "date-time" back into "df", and assign it as the new index.

df = df.join(df1['date']).set_index('date')
df
# Out:
#                   c_year c_mnth c_wday c_hour  c_sev c_vehs c_conf c_rcfg  \
# date
# 2013-06-2 12:0:0    2013     06      2     12      2     02     21     02
# 2013-06-2 09:0:0    2013     06      2     09      2     01     06     02
# 2013-06-2 09:0:0    2013     06      2     09      2     01     06     02
# ...                  ...    ...    ...    ...    ...    ...    ...    ...
# 2014-12-7 19:0:0    2014     12      7     19      2     01     03     01
# 2014-12-7 19:0:0    2014     12      7     19      2     01     03     01
# 2014-12-7 19:0:0    2014     12      7     19      2     01     03     01
#
#                  c_wthr c_rsur  ...   v_id v_type v_year p_id p_sex p_age  \
# date                            ...
# 2013-06-2 12:0:0      1      1  ...     02     01   2005   01     M    28
# 2013-06-2 09:0:0      1      1  ...     01     11   2008   01     F    42
# 2013-06-2 09:0:0      1      1  ...     01     11   2008   02     M    04
# ...                 ...    ...  ...    ...    ...    ...  ...   ...   ...
# 2014-12-7 19:0:0      1      3  ...     01     01   2001   01     F    35
# 2014-12-7 19:0:0      1      3  ...     01     01   2001   02     M    26
# 2014-12-7 19:0:0      1      3  ...     01     01   2001   03     F    15
#
#                  p_psn p_isev p_safe p_user
# date
# 2013-06-2 12:0:0    11      2     02      1
# 2013-06-2 09:0:0    11      1     02      1
# 2013-06-2 09:0:0    12      2     01      2
# ...                ...    ...    ...    ...
# 2014-12-7 19:0:0    11      2     02      1
# 2014-12-7 19:0:0    13      1     02      2
# 2014-12-7 19:0:0    21      2     02      2
#
# [488078 rows x 22 columns]

# %%
# create a new dataframe "dfa" to avoid mess up "df".  Use "dfa" for analysis below

dfa = df.iloc[:,4:]
dfa
# Out:
#                   c_sev c_vehs c_conf c_rcfg c_wthr c_rsur c_raln c_traf v_id  \
# date
# 2013-06-2 12:0:0      2     02     21     02      1      1      1     01   02
# 2013-06-2 09:0:0      2     01     06     02      1      1      1     18   01
# 2013-06-2 09:0:0      2     01     06     02      1      1      1     18   01
# ...                 ...    ...    ...    ...    ...    ...    ...    ...  ...
# 2014-12-7 19:0:0      2     01     03     01      1      3      4     18   01
# 2014-12-7 19:0:0      2     01     03     01      1      3      4     18   01
# 2014-12-7 19:0:0      2     01     03     01      1      3      4     18   01
#
#                  v_type v_year p_id p_sex p_age p_psn p_isev p_safe p_user
# date
# 2013-06-2 12:0:0     01   2005   01     M    28    11      2     02      1
# 2013-06-2 09:0:0     11   2008   01     F    42    11      1     02      1
# 2013-06-2 09:0:0     11   2008   02     M    04    12      2     01      2
# ...                 ...    ...  ...   ...   ...   ...    ...    ...    ...
# 2014-12-7 19:0:0     01   2001   01     F    35    11      2     02      1
# 2014-12-7 19:0:0     01   2001   02     M    26    13      1     02      2
# 2014-12-7 19:0:0     01   2001   03     F    15    21      2     02      2
#
# [488078 rows x 18 columns]

# %%
dfa.isnull().sum().sort_values()
# Out:
# c_sev     0
# p_isev    0
# p_psn     0
#          ..
# p_safe    0
# p_user    0
# c_vehs    3
# Length: 18, dtype: int64

# %%
dfa[dfa['c_vehs'].isnull()]
# Out:
#                   c_sev c_vehs c_conf c_rcfg c_wthr c_rsur c_raln c_traf v_id  \
# date
# 2013-07-3 16:0:0      2    NaN     QQ     01      1      1      3     UU   99
# 2013-07-3 16:0:0      2    NaN     QQ     01      1      1      3     UU   99
# 2013-10-6 15:0:0      2    NaN     QQ     UU      1      Q      1     UU   99
#
#                  v_type v_year p_id p_sex p_age p_psn p_isev p_safe p_user
# date
# 2013-07-3 16:0:0     NN   NNNN   01     M    19    99      2     NN      3
# 2013-07-3 16:0:0     NN   NNNN   02     M    18    99      1     NN      3
# 2013-10-6 15:0:0     NN   NNNN   01     M    54    99      2     NN      3
